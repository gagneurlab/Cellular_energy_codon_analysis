# %% [markdown]
# # Get the sequences from a gtf annotation and the corresponding fasta file

# %%
from mrna_dataloader_general import MRNA_halflife_dl

#This files can be downloaded from the gencode website (https://www.gencodegenes.org/human/release_25.html)
gtf_path =  '../../data/gencode.v25.annotation.gtf.gz'
fasta_path = '../../data/hg38.fa'

mrna_hl_dl = MRNA_halflife_dl(gtf_file_path=gtf_path, fasta_file_path=fasta_path,
                              mrna_region='cds', get_codon_number=True, u_aug_search=False)

# %%
mrna_hl_dl.gtf
# Out:
#         Chromosome   Source     Feature  Start    End Score Strand Frame  \
# 0             chr1   HAVANA        gene  11868  14409     .      +     .
# 1             chr1   HAVANA  transcript  11868  14409     .      +     .
# 2             chr1   HAVANA        exon  11868  12227     .      +     .
# 3             chr1   HAVANA        exon  12612  12721     .      +     .
# 4             chr1   HAVANA        exon  13220  14409     .      +     .
# ...            ...      ...         ...    ...    ...   ...    ...   ...
# 2579812       chrM  ENSEMBL  transcript  15887  15953     .      +     .
# 2579813       chrM  ENSEMBL        exon  15887  15953     .      +     .
# 2579814       chrM  ENSEMBL        gene  15955  16023     .      -     .
# 2579815       chrM  ENSEMBL  transcript  15955  16023     .      -     .
# 2579816       chrM  ENSEMBL        exon  15955  16023     .      -     .
#
#                    gene_id                           gene_type  ...  \
# ...

# %%
mrna_hl_dl[3]
# Out:
# {'chromosome': 'chr1',
#  'gene_id': 'ENSG00000279457.3',
#  'transcript_id': 'ENST00000623083.3',
#  'cds': '...',
#  'non_AUG': False,
#  'codon_numbers':      codon number
#  AAA           1.0
#  AAC           6.0
#  AAG          29.0
#  AAT           0.0
#  ACA           3.0
#  ..            ...
#  TGT           0.0
#  TTA           0.0
#  TTC           8.0
#  TTG           4.0
#  TTT           3.0
#
#  [64 rows x 1 columns]}

# %% [markdown]
# The sequences are stored into a pickle file, in this case "loaded_seqs_gencode25". The other stored sequences were saved under the name "loaded_data_gencode19"

# %%
data = mrna_hl_dl.load_data(save_path="loaded_seqs_gencode25")
# Out:
# loading_data...
# 0.000000 per cent completed
# 1.065008 per cent completed
# 2.130016 per cent completed
# 3.195024 per cent completed
# 4.260032 per cent completed
# 5.325040 per cent completed
# 6.390049 per cent completed
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/modules/i12g/anaconda/envs/mrna_halflife2/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-0801ceed91e6>", line 1, in <module>
#     data = mrna_hl_dl.load_data(save_path="loaded_seqs_gencode25")
#   File "/data/nasif12/home_if12/tomazdas/Projects/mrna-halflife/data_utils/mrna_dataloader_general.py", line 185, in load_data
#     for transcript_i, mrna in enumerate(self):
# ...
